# %% [markdown]
# # Linear Regression
#
# A linear regression learning algorithm example using TensorFlow library.

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
rng = numpy.random

# %%
# Parameters
learning_rate = 0.01
training_epochs = 10
display_step = 1

# %%
# Training Data
train_X = numpy.asarray([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
train_Y = numpy.asarray([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])
n_samples = train_X.shape[0]
print(train_X.shape[0])
# Out:
# 17

# %%
# tf Graph Input
X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
W = tf.Variable(rng.randn(), name="weight")
b = tf.Variable(rng.randn(), name="bias")

# %%
# Construct a linear model
pred = tf.add(tf.multiply(X, W), b)

# %%
# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
# Start training
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs):
        for (x, y) in zip(train_X, train_Y):
            j,k=sess.run([optimizer,cost], feed_dict={X: x, Y: y})
            costs.write(epoch,k).mark_used()
             
        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "W=", sess.run(W), "b=", sess.run(b))

    print ("Optimization Finished!")
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "W=", sess.run(W), "b=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(W) * train_X + sess.run(b), label='Fitted line')
    plt.legend()
    plt.show()
    print(sess.run(costs))
    '''
    plt2.plot(range(1000), costs, 'ro', label='Original data')
    plt2.legend()
    plt2.show()
    '''
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC4E0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC208>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py", line 842, in write
#     return self._implementation.write(index, value, name=name)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC208>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CCB70>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py", line 842, in write
#     return self._implementation.write(index, value, name=name)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CCB70>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC898>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py", line 842, in write
#     return self._implementation.write(index, value, name=name)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC668>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC240>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py", line 842, in write
#     return self._implementation.write(index, value, name=name)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC240>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE50CC898>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
# ...
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE68307F0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py", line 842, in write
#     return self._implementation.write(index, value, name=name)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE34A0DA0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000013BE6830D30>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-166-c55733e3a099>", line 9, in <module>
#     costs.write(epoch,k)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py", line 842, in write
#     return self._implementation.write(index, value, name=name)  File "C:\Users\Divyanshu\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 189, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================

# %%
# Regression result
